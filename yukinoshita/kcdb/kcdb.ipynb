# %%
import pandas as pd
import numpy as np
from kcdb_engine import get_kc_rawdata

# %%
df_raw = get_kc_rawdata()
df_raw
df_mod = df_raw['Drop'] == '5500'
# Out:
#                       Time                             World       Node  \
# 0      2024/09/23 14:22:59  北大西洋/フリータウン/ダカール(59-3 %rank) | 4  49(Boss点)
# 1      2024/09/23 14:19:54  北大西洋/フリータウン/ダカール(59-3 %rank) | 4     45(道中)
# 2      2024/09/23 14:18:59  北大西洋/フリータウン/ダカール(59-3 %rank) | 4      基地防空戦
# 3      2024/09/23 14:17:38  北大西洋/フリータウン/ダカール(59-3 %rank) | 4     38(道中)
# 4      2024/09/23 14:15:55  北大西洋/フリータウン/ダカール(59-3 %rank) | 4     47(道中)
# ...                    ...                               ...        ...
# 83337  2021/11/27 16:17:29         昭南方面～本土航路(52-2 %rank) | 4      1(道中)
# 83338  2021/11/27 16:16:36         昭南方面～本土航路(52-2 %rank) | 4      5(道中)
# 83339  2021/11/27 16:15:52         昭南方面～本土航路(52-2 %rank) | 4      1(道中)
# 83340  2021/11/27 16:13:16                        珊瑚諸島沖(5-2)      3(道中)
# 83341  2021/11/27 16:11:44                        珊瑚諸島沖(5-2)      3(道中)
#
#       Sortie Type      Battle Result    Enemy Encounters Drop Heavily Damaged  \
# ...
